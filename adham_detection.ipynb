# %%
from ultralytics import YOLO
from google.colab import files
from IPython.display import Video
import os
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo11n.pt")

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0efa2fae-70ee-4976-86d2-8c7940d89108" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0efa2fae-70ee-4976-86d2-8c7940d89108">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

# %%
results = model.predict(
    source="/content/people.mp4",
    save=True,
    conf=0.25
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/345) /content/people.mp4: 384x640 17 persons, 149.9ms
# video 1/1 (frame 2/345) /content/people.mp4: 384x640 17 persons, 134.0ms
# video 1/1 (frame 3/345) /content/people.mp4: 384x640 18 persons, 134.3ms
# video 1/1 (frame 4/345) /content/people.mp4: 384x640 18 persons, 131.3ms
# video 1/1 (frame 5/345) /content/people.mp4: 384x640 18 persons, 140.3ms
# ...

# %%
import os

print(os.listdir("/content/runs/detect"))
# Out:
# ['predict-3', 'predict-2', 'predict']

# %%
import glob

print(glob.glob("/content/runs/detect/**/*", recursive=True))
# Out:
# ['/content/runs/detect/predict-3', '/content/runs/detect/predict-2', '/content/runs/detect/predict', '/content/runs/detect/predict-3/people.avi', '/content/runs/detect/predict-2/people (1).avi', '/content/runs/detect/predict-2/people.avi', '/content/runs/detect/predict/people.avi']

# %%
import glob

videos = glob.glob("/content/runs/detect/**/*.avi", recursive=True)
print(videos)
# Out:
# ['/content/runs/detect/predict-3/people.avi', '/content/runs/detect/predict-2/people (1).avi', '/content/runs/detect/predict-2/people.avi', '/content/runs/detect/predict/people.avi']

# %%
from google.colab import files

files.download(videos[0])

# %%
# !ffmpeg -i "/content/runs/detect/predict/people.avi" -vcodec libx264 "/content/people_detected.mp4"
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from IPython.display import Video

Video("/content/people_detected.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
